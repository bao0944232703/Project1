# %%
import pandas as pd
df=pd.read_csv('UserCarData_Clean.csv')

# %%
df[df['name'].str.contains('Volvo')]
# https://www.car.info/en-se/volvo/xc40/xc40-d4-awd-ma8-2018-16517632/specs
# Out:
#       Unnamed: 0  Sales_ID   name  year  selling_price  km_driven   Region  \
# 648          156       171  Volvo  2017       10000000      30000     East
# 846          354       389  Volvo  2018        2475000       2000  Central
# 879          387       428  Volvo  2018        2475000       2000     West
# 1102         610       665  Volvo  2018        2475000       2000     East
# 1487         995      1096  Volvo  2018        2475000       2000    South
# ...          ...       ...    ...   ...            ...        ...      ...
# 7898        6508      6694  Volvo  2019        3800000      20000     West
# 7899        6770      6964  Volvo  2019        3800000      20000     West
# 7902        7307      7517  Volvo  2018        5500000      50000  Central
# 7904        7644      7863  Volvo  2019        3800000      20000  Central
# 7905        7712      7931  Volvo  2019        5500000      17000    South
#
# ...

# %%
# filter những động cơ có max power = 190 và torque 400Nm để nhập số vòng xoay 'rpm' vào 1,750 - 2,500
# https://www.car.info/en-se/volvo/xc40/xc40-d4-awd-ma8-2018-16517632/specs
df3.loc[(df3['max_power']==190) & (df3['torque']==400),'rpm'] = '1,750 - 2,500'

# %%
df[df['name'].str.contains('Volvo')]
# Out:
#       Unnamed: 0  Sales_ID   name  year  selling_price  km_driven   Region  \
# 648          156       171  Volvo  2017       10000000      30000     East
# 846          354       389  Volvo  2018        2475000       2000  Central
# 879          387       428  Volvo  2018        2475000       2000     West
# 1102         610       665  Volvo  2018        2475000       2000     East
# 1487         995      1096  Volvo  2018        2475000       2000    South
# ...          ...       ...    ...   ...            ...        ...      ...
# 7898        6508      6694  Volvo  2019        3800000      20000     West
# 7899        6770      6964  Volvo  2019        3800000      20000     West
# 7902        7307      7517  Volvo  2018        5500000      50000  Central
# 7904        7644      7863  Volvo  2019        3800000      20000  Central
# 7905        7712      7931  Volvo  2019        5500000      17000    South
#
# ...

# %%
# filter những động cơ có max power = 235 và torque 480Nm để nhập số vòng xoay 'rpm' vào 1,750 - 2,250
df3.loc[(df3['max_power']==235) & (df3['torque']==480),'rpm'] = '1,750 - 2,250'

# %%
df[['rpm_min','rpm_max']]=df['rpm'].str.split("-",expand = True)

# %%
df.drop(columns='rpm')
# Out:
#       Unnamed: 0  Sales_ID     name  year  selling_price  km_driven   Region  \
# 0              0         3    Honda  2006         158000     140000  Central
# 1              1         4  Hyundai  2010         225000     127000  Central
# 2              2         5   Maruti  2007         130000     120000     East
# 3              3         7   Maruti  2007          96000     175000     West
# 4              4        18  Hyundai  2012         500000      53000  Central
# ...          ...       ...      ...   ...            ...        ...      ...
# 7901        7096      7297    Skoda  2010         355000     116000  Central
# 7902        7307      7517    Volvo  2018        5500000      50000  Central
# 7903        7322      7533    Skoda  2007         195000     175000  Central
# 7904        7644      7863    Volvo  2019        3800000      20000  Central
# 7905        7712      7931    Volvo  2019        5500000      17000    South
#
# ...

# %%
# Hàm lọc cột 'rpm_max' có giá trị là None/Null thì sẽ gán bằng giá trị rpm_min
df.loc[df['rpm_max'].isnull(),'rpm_max'] = df['rpm_min']

# %%
# index lại các cột
df=df[['Sales_ID','name','year','selling_price','km_driven','Region','State or Province','City','fuel','seller_type','transmission','owner','mileage','engine','max_power','torque','rpm_min','rpm_max','seats','sold']]

# %%
df['rpm_min']=df['rpm_min'].str.replace(',','',regex = False)

# %%
df['rpm_max']=df['rpm_max'].str.replace(',','',regex = False)

# %%
df['rpm_min']=df['rpm_min'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-e233dfcb1786> in <cell line: 1>()
# ----> 1 df['rpm_min']=df['rpm_min'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df.to_csv('UserCarData_Clean_rev1.csv')

# %%
### hàm để thay giá trị NAN trong cột'rpm' thành giá trị cần '1,750 - 2,500' ( Ko Dùng, học để biết thêm)
df['rpm'].fillna('1,750 - 2,500',inplace = True)

# %%
#data_df[pd.to_numeric(data_df['value'], errors='coerce').notna()]
df[pd.to_numeric(df['rpm_min'],errors='coerce')]
# Out:
# <ipython-input-41-7bcc2ce7b8d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[pd.to_numeric(df['rpm_min'],errors='coerce')] = False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           7906 non-null   int64
#  1   name               7906 non-null   object
#  2   year               7906 non-null   int64
#  3   selling_price      7906 non-null   int64
#  4   km_driven          7906 non-null   int64
#  5   Region             7906 non-null   object
#  6   State or Province  7906 non-null   object
#  7   City               7906 non-null   object
#  8   fuel               7906 non-null   object
#  9   seller_type        7906 non-null   object
#  10  transmission       7906 non-null   object
#  11  owner              7906 non-null   object
#  12  mileage            7906 non-null   float64
#  13  engine             7906 non-null   int64
#  14  max_power          7906 non-null   float64
#  15  torque             7906 non-null   float64
# ...

# %%
df[df['name'].str.contains('Volvo')]
# Out:
#       Unnamed: 0  Sales_ID   name  year  selling_price  km_driven   Region  \
# 648          156       171  Volvo  2017       10000000      30000     East
# 846          354       389  Volvo  2018        2475000       2000  Central
# 879          387       428  Volvo  2018        2475000       2000     West
# 1102         610       665  Volvo  2018        2475000       2000     East
# 1487         995      1096  Volvo  2018        2475000       2000    South
# ...          ...       ...    ...   ...            ...        ...      ...
# 7898        6508      6694  Volvo  2019        3800000      20000     West
# 7899        6770      6964  Volvo  2019        3800000      20000     West
# 7902        7307      7517  Volvo  2018        5500000      50000  Central
# 7904        7644      7863  Volvo  2019        3800000      20000  Central
# 7905        7712      7931  Volvo  2019        5500000      17000    South
#
# ...
