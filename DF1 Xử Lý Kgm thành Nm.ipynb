# %%
import pandas as pd
df = pd.read_csv('UserCarData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           7906 non-null   int64
#  1   name               7906 non-null   object
#  2   year               7906 non-null   int64
#  3   selling_price      7906 non-null   int64
#  4   km_driven          7906 non-null   int64
#  5   Region             7906 non-null   object
#  6   State or Province  7906 non-null   object
#  7   City               7906 non-null   object
#  8   fuel               7906 non-null   object
#  9   seller_type        7906 non-null   object
#  10  transmission       7906 non-null   object
#  11  owner              7906 non-null   object
#  12  mileage            7906 non-null   float64
#  13  engine             7906 non-null   int64
#  14  max_power          7906 non-null   float64
#  15  torque             7906 non-null   object
# ...

# %%
df.describe()
# Out:
#           Sales_ID         year  selling_price     km_driven      mileage  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04    19.419861
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04     4.036263
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00     0.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04    16.780000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04    19.300000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04    22.320000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06    42.000000
#
#             engine    max_power        seats
# count  7906.000000  7906.000000  7906.000000
# mean   1458.708829    91.587374     5.416393
# std     503.893057    35.747216     0.959208
# min     624.000000    32.800000     2.000000
# 25%    1197.000000    68.050000     5.000000
# ...

# %%
df
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 0            1   Maruti  2014         450000     145500     East
# 1            2    Skoda  2014         370000     120000     East
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# ...        ...      ...   ...            ...        ...      ...
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7902      8125  Hyundai  2007         135000     119000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#          State or Province           City    fuel seller_type transmission  \
# 0     District of Columbia     Washington  Diesel  Individual       Manual
# ...

# %%
df.groupby(by='owner').agg({'owner':'count'})
# Out:
#                     owner
# owner
# First_Owner          5215
# Fourth_Above_Owner    160
# Second_Owner         2016
# Test_Drive_Car          5
# Third_Owner           510

# %%
df.groupby(by='State or Province').agg({'State or Province':'count'})
# Out:
#                       State or Province
# State or Province
# Alabama                             106
# Arizona                             115
# Arkansas                            107
# California                          901
# Colorado                            154
# Connecticut                          63
# Delaware                             15
# District of Columbia                 68
# Florida                             425
# Georgia                             187
# Idaho                                89
# Illinois                            489
# Indiana                             213
# Iowa                                123
# Kansas                              112
# Kentucky                             55
# Louisiana                            66
# Maine                               110
# Maryland                            144
# Massachusetts                       191
# Michigan                            305
# Minnesota                           169
# ...

# %%
df1=df[df.torque.str.contains('kgm')]

# %%
# xóa ký tự "kgm@ rpm" trong cột torque
df1['torque']=df1['torque'].str.replace('(kgm@ rpm)','',regex=True)
# Out:
# <ipython-input-50-61fbf2a604e5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque']=df1['torque'].str.replace('(kgm@ rpm)','',regex=True)

# %%
df1
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# 6            7   Maruti  2007          96000     175000     West
# 16          18  Hyundai  2012         500000      53000  Central
# ...        ...      ...   ...            ...        ...      ...
# 7861      8083     Ford  2007         125000     110000     West
# 7882      8105    Honda  2006         160000      70000     West
# 7883      8106    Honda  2004         135000     120000     West
# 7891      8114   Toyota  2010         425000     129000    South
# 7902      8125  Hyundai  2007         135000     119000  Central
#
#      State or Province           City    fuel seller_type transmission  \
# 2             Illinois        Chicago  Petrol  Individual       Manual
# ...

# %%
# xóa ký tự "kgm" trong cột torque
df1['torque']=df1['torque'].str.replace('kgm','',regex=True)
# Out:
# <ipython-input-52-fdc4ee188a08>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque']=df1['torque'].str.replace('kgm','',regex=True)

# %%
df1
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# 6            7   Maruti  2007          96000     175000     West
# 16          18  Hyundai  2012         500000      53000  Central
# ...        ...      ...   ...            ...        ...      ...
# 7861      8083     Ford  2007         125000     110000     West
# 7882      8105    Honda  2006         160000      70000     West
# 7883      8106    Honda  2004         135000     120000     West
# 7891      8114   Toyota  2010         425000     129000    South
# 7902      8125  Hyundai  2007         135000     119000  Central
#
#      State or Province           City    fuel seller_type transmission  \
# 2             Illinois        Chicago  Petrol  Individual       Manual
# ...

# %%
# thay thế ký tự "at" thành "@" trong cột torque
df1['torque']=df1['torque'].str.replace('at','@',regex=True)
# Out:
# <ipython-input-54-42e46feb1133>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque']=df1['torque'].str.replace('at','@',regex=True)

# %%
df1
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# 6            7   Maruti  2007          96000     175000     West
# 16          18  Hyundai  2012         500000      53000  Central
# ...        ...      ...   ...            ...        ...      ...
# 7861      8083     Ford  2007         125000     110000     West
# 7882      8105    Honda  2006         160000      70000     West
# 7883      8106    Honda  2004         135000     120000     West
# 7891      8114   Toyota  2010         425000     129000    South
# 7902      8125  Hyundai  2007         135000     119000  Central
#
#      State or Province           City    fuel seller_type transmission  \
# 2             Illinois        Chicago  Petrol  Individual       Manual
# ...

# %%
# Xóa ký tự "rpm" trong cột torque
df1['torque']=df1['torque'].str.replace('rpm','',regex=True)
# Out:
# <ipython-input-58-39db458a2481>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['torque']=df1['torque'].str.replace('rpm','',regex=True)

# %%
df1
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# 6            7   Maruti  2007          96000     175000     West
# 16          18  Hyundai  2012         500000      53000  Central
# ...        ...      ...   ...            ...        ...      ...
# 7861      8083     Ford  2007         125000     110000     West
# 7882      8105    Honda  2006         160000      70000     West
# 7883      8106    Honda  2004         135000     120000     West
# 7891      8114   Toyota  2010         425000     129000    South
# 7902      8125  Hyundai  2007         135000     119000  Central
#
#      State or Province           City    fuel seller_type transmission  \
# 2             Illinois        Chicago  Petrol  Individual       Manual
# ...

# %%
df1[['torque1','rpm']]=df1['torque'].str.split("@",expand = True)
# Out:
# <ipython-input-62-61cfd87ddbdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['torque1','rpm']]=df1['torque'].str.split("@",expand = True)
# <ipython-input-62-61cfd87ddbdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['torque1','rpm']]=df1['torque'].str.split("@",expand = True)

# %%
df1=df1.drop(columns=['torque'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 2 to 7902
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           492 non-null    int64
#  1   name               492 non-null    object
#  2   year               492 non-null    int64
#  3   selling_price      492 non-null    int64
#  4   km_driven          492 non-null    int64
#  5   Region             492 non-null    object
#  6   State or Province  492 non-null    object
#  7   City               492 non-null    object
#  8   fuel               492 non-null    object
#  9   seller_type        492 non-null    object
#  10  transmission       492 non-null    object
#  11  owner              492 non-null    object
#  12  mileage            492 non-null    float64
#  13  engine             492 non-null    int64
#  14  max_power          492 non-null    float64
#  15  seats              492 non-null    int64
# ...

# %%
df1['torque1']=df1['torque1'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-359164701501> in <cell line: 1>()
# ----> 1 df1['torque1']=df1['torque1'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
# Xóa ký tự "Nm" trong cột torque1 bị lỗi
df1['torque1']=df1['torque1'].str.replace('Nm','',regex=True)

# %%
df1['torque1']=df1['torque1'].astype(float)
# đổi kiểu biến từ object sang float thì báo lỗi sai định dạng trong cột 'torque1'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-359164701501> in <cell line: 1>()
# ----> 1 df1['torque1']=df1['torque1'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df1[df1.torque1.str.contains('380')]
# Out:
#      Sales_ID  name  year  selling_price  km_driven   Region  \
# 751       779  Ford  2013        1075000     110000  Central
#
#     State or Province     City    fuel seller_type transmission        owner  \
# 751          Michigan  Detroit  Diesel  Individual    Automatic  Third_Owner
#
#      mileage  engine  max_power  seats sold    torque1    rpm
# 751     12.8    2953      156.0      7    Y  380(38.7)   2500

# %%
# xuất ra file CSV để xử lý dòng Index 751 xóa 380 và phá ngoặc trong rpm
df1.to_csv('UserCarData1.csv')

# %%
df1=pd.read_csv('UserCarData1.csv')

# %%
df1
# Out:
#      Unnamed: 0  Sales_ID     name  year  selling_price  km_driven   Region  \
# 0             2         3    Honda  2006         158000     140000  Central
# 1             3         4  Hyundai  2010         225000     127000  Central
# 2             4         5   Maruti  2007         130000     120000     East
# 3             6         7   Maruti  2007          96000     175000     West
# 4            16        18  Hyundai  2012         500000      53000  Central
# ..          ...       ...      ...   ...            ...        ...      ...
# 487        7861      8083     Ford  2007         125000     110000     West
# 488        7882      8105    Honda  2006         160000      70000     West
# 489        7883      8106    Honda  2004         135000     120000     West
# 490        7891      8114   Toyota  2010         425000     129000    South
# 491        7902      8125  Hyundai  2007         135000     119000  Central
#
# ...

# %%
df1['torque1']=df1['torque1'].astype(float)

# %%
# chuyển đổi đơn vị từ kgm thành Nm
df1['torque1']=df1['torque1']*9.8

# %%
# Đổi tên cột từ "torque1" thành "torque"
df1=df1.rename(columns={'torque1':'torque'})

# %%
# Re-index columns lại
df1=df1[['Sales_ID','name','year','selling_price','km_driven','Region','State or Province','City','fuel','seller_type','transmission','owner','mileage','engine','max_power','torque','rpm','seats','sold']]

# %%
df1
# Out:
#      Sales_ID     name  year  selling_price  km_driven   Region  \
# 0           3    Honda  2006         158000     140000  Central
# 1           4  Hyundai  2010         225000     127000  Central
# 2           5   Maruti  2007         130000     120000     East
# 3           7   Maruti  2007          96000     175000     West
# 4          18  Hyundai  2012         500000      53000  Central
# ..        ...      ...   ...            ...        ...      ...
# 487      8083     Ford  2007         125000     110000     West
# 488      8105    Honda  2006         160000      70000     West
# 489      8106    Honda  2004         135000     120000     West
# 490      8114   Toyota  2010         425000     129000    South
# 491      8125  Hyundai  2007         135000     119000  Central
#
#     State or Province           City    fuel seller_type transmission  \
# 0            Illinois        Chicago  Petrol  Individual       Manual
# ...

# %% [markdown]
# Xử Lý Dãy số liệu torque theo NM. Tách ra bảng df2

# %%
df2=df[df.torque.str.contains('kgm')==False]

# %%
df2['torque']=df2['torque'].str.replace('Nm','',regex=True)
# Out:
# <ipython-input-137-459cb8526b39>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['torque']=df2['torque'].str.replace('Nm' or 'nm','',regex=True)

# %%
df2['torque']=df2['torque'].str.replace('at','@',regex=True)
# Out:
# <ipython-input-138-f0b354f03c83>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['torque']=df2['torque'].str.replace('at','@',regex=True)

# %%
df2['torque']=df2['torque'].str.replace('rpm','',regex=True)
# Out:
# <ipython-input-139-207257414275>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['torque']=df2['torque'].str.replace('rpm','',regex=True)

# %%
df2.to_csv('UserCarData2.csv')

# %%
df2['torque']=df2['torque'].str.replace('nm','',regex=True)
# Out:
# <ipython-input-140-334ba59240fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['torque']=df2['torque'].str.replace('nm','',regex=True)

# %%
df2
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 0            1   Maruti  2014         450000     145500     East
# 1            2    Skoda  2014         370000     120000     East
# 5            6  Hyundai  2017         440000      45000     East
# 7            8   Maruti  2001          45000       5000     West
# 8            9   Toyota  2011         350000      90000     West
# ...        ...      ...   ...            ...        ...      ...
# 7900      8123  Hyundai  2014         475000      80000  Central
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#          State or Province           City    fuel seller_type transmission  \
# 0     District of Columbia     Washington  Diesel  Individual       Manual
# ...

# %%
df2=df2[df2.torque.str.contains('@')]

# %%
df2.to_csv('UserCarData3.csv')

# %%
df2=pd.read_csv('UserCarData3.csv')

# %%
df2[['torque1','rpm']]=df2['torque'].str.split("@",expand = True,regex=False)

# %%
df2['torque1']=df2['torque1'].str.replace('KGM','',regex=True)

# %%
df2['torque1']=df2['torque1'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-b03fe1ab2153> in <cell line: 1>()
# ----> 1 df2['torque1']=df2['torque1'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df2['torque1']=df2['torque1'].str.replace('KGM','',regex=True)

# %%
df2['torque1']=df2['torque1'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-b03fe1ab2153> in <cell line: 1>()
# ----> 1 df2['torque1']=df2['torque1'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# ...

# %%
df2['torque1']=df2['torque1'].str.replace('NM','',regex=True)

# %%
df2['torque1']=df2['torque1'].astype(float)

# %%
df2=df2.drop(columns=['torque'])

# %%
df2=df2.rename(columns={'torque1':'torque'})

# %%
df2=df2[['Sales_ID','name','year','selling_price','km_driven','Region','State or Province','City','fuel','seller_type','transmission','owner','mileage','engine','max_power','torque','rpm','seats','sold']]

# %% [markdown]
# Tách DF3 thêm từ DF2 là danh sách ko có ký tự "@" ở Torque

# %%
df3=df2[df2.torque.str.contains('@') == False]

# %%
df3
# Out:
#       Sales_ID   name  year  selling_price  km_driven   Region  \
# 139        146  Volvo  2018        3400000      22000     East
# 361        375  Volvo  2019        3800000      20000  Central
# 399        414  Volvo  2019        3800000      20000     West
# 631        651  Volvo  2019        3800000      20000  Central
# 1050      1082  Volvo  2019        3800000      20000  Central
# 1069      1101  Volvo  2019        3800000      20000    South
# 1088      1120  Volvo  2019        3800000      20000     East
# 1107      1139  Volvo  2019        3800000      20000    South
# 1663      1714  Volvo  2019        3800000      20000    South
# 1774      1829  Volvo  2019        3800000      20000  Central
# 2073      2138   Land  2013        1650000      64788  Central
# 2548      2635  Volvo  2019        3800000      20000  Central
# 2581      2668  Volvo  2019        3800000      20000     East
# 2986      3083  Volvo  2019        3800000      20000  Central
# ...

# %%
df3[['torque1','rpm']]=df3['torque'].str.split("/",expand = True)
# Out:
# <ipython-input-173-dfa3613a3b77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[['torque1','rpm']]=df3['torque'].str.split("/",expand = True)
# <ipython-input-173-dfa3613a3b77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3[['torque1','rpm']]=df3['torque'].str.split("/",expand = True)

# %%
df3=df3.drop(columns=['torque'])

# %%
df3=df3.rename(columns={'torque1':'torque'})

# %%
df3=df3[['Sales_ID','name','year','selling_price','km_driven','Region','State or Province','City','fuel','seller_type','transmission','owner','mileage','engine','max_power','torque','rpm','seats','sold']]

# %%
df3
# Out:
#       Sales_ID   name  year  selling_price  km_driven   Region  \
# 139        146  Volvo  2018        3400000      22000     East
# 361        375  Volvo  2019        3800000      20000  Central
# 399        414  Volvo  2019        3800000      20000     West
# 631        651  Volvo  2019        3800000      20000  Central
# 1050      1082  Volvo  2019        3800000      20000  Central
# 1069      1101  Volvo  2019        3800000      20000    South
# 1088      1120  Volvo  2019        3800000      20000     East
# 1107      1139  Volvo  2019        3800000      20000    South
# 1663      1714  Volvo  2019        3800000      20000    South
# 1774      1829  Volvo  2019        3800000      20000  Central
# 2073      2138   Land  2013        1650000      64788  Central
# 2548      2635  Volvo  2019        3800000      20000  Central
# 2581      2668  Volvo  2019        3800000      20000     East
# 2986      3083  Volvo  2019        3800000      20000  Central
# ...

# %%
df_new= pd.concat([df1,df2,df3])

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 7712
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           7906 non-null   int64
#  1   name               7906 non-null   object
#  2   year               7906 non-null   int64
#  3   selling_price      7906 non-null   int64
#  4   km_driven          7906 non-null   int64
#  5   Region             7906 non-null   object
#  6   State or Province  7906 non-null   object
#  7   City               7906 non-null   object
#  8   fuel               7906 non-null   object
#  9   seller_type        7906 non-null   object
#  10  transmission       7906 non-null   object
#  11  owner              7906 non-null   object
#  12  mileage            7906 non-null   float64
#  13  engine             7906 non-null   int64
#  14  max_power          7906 non-null   float64
#  15  torque             7906 non-null   object
# ...

# %%
df_new.describe()
# Out:
#           Sales_ID         year  selling_price     km_driven      mileage  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04    19.419861
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04     4.036263
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00     0.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04    16.780000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04    19.300000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04    22.320000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06    42.000000
#
#             engine    max_power        seats
# count  7906.000000  7906.000000  7906.000000
# mean   1458.708829    91.587374     5.416393
# std     503.893057    35.747216     0.959208
# min     624.000000    32.800000     2.000000
# 25%    1197.000000    68.050000     5.000000
# ...

# %%
df_new.to_csv('UserCarData_Clean.csv')
